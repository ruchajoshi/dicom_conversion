# %%
import pydicom

dicom_path = r"C:\Users\r.joshi\Downloads\01_11_2024\7139000004\COMBI\L\ultrasound.46.dcm"
dicom_data = pydicom.dcmread(dicom_path)

# Print all metadata
print(dicom_data)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 188
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Ultrasound Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.528.1.1007.189.1.32899.780061928.308
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.528.1.1007.189.1
# (0002,0013) Implementation Version Name         SH: 'SB_2_4_0'
# (0002,0016) Source Application Entity Title     AE: 'Smoothbase'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'TEE', '1']
# (0008,0016) SOP Class UID                       UI: Ultrasound Image Storage
# ...

# %%
dicom_path = r"C:\Users\r.joshi\Downloads\01_11_2024\7139000004\COMBI\L\rtss.dcm"
dicom_data = pydicom.dcmread(dicom_path)

# Print all metadata
print(dicom_data)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 190
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.528.1.1007.189.1.32899.780061928.348
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.528.1.1007.189.1
# (0002,0013) Implementation Version Name         SH: 'SB_2_4_0'
# (0002,0016) Source Application Entity Title     AE: 'Smoothbase'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008,0018) SOP Instance UID                    UI: 1.2.528.1.1007.189.1.32899.780061928.348
# (0008,0020) Study Date                          DA: '19010101'
# ...
